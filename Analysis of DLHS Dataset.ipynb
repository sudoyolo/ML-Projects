# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/onkarmahapatra/Desktop/DLHS-3_district/movement_maps_data.csv')
df2 = pd.read_csv('/Users/onkarmahapatra/Desktop/DLHS-3_district/Movements.csv')

# %%
df1
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
names1 = (df1["start_polygon_name"].unique())
n = len(pd.unique(df1['start_polygon_name']))
n
# Out:
# 854

# %%
names2 = (df2["polygon_name"].unique())
n = len(pd.unique(df2['polygon_name']))
n
# Out:
# 650

# %%
one_not_two = set(df1["start_polygon_name"]).difference(df2['polygon_name'])
one_not_two
n1 = len(one_not_two)
n1
one_not_two
# Out:
# {'Abbottabad',
#  'Aceh Besar',
#  'Aceh Jaya',
#  'Aceh Tengah',
#  'Aceh Utara',
#  'Anjaw',
#  'Attock',
#  'Ayeyarwady',
#  'Badin',
#  'Bagmati',
#  'Bago',
#  'Bahawalnagar',
#  'Bahawalpur',
#  'Bajaur',
#  'Baloda Bazaar',
#  'Bannu',
#  'Bara Banki',
#  'Baramula',
#  'Barisal',
#  'Barkhan',
#  'Batagram',
#  'Baudh',
#  'Bhakkar',
#  'Bheri',
#  'Bireuen',
#  'Bumthang',
#  'Buner',
#  'Central',
#  'Chakwal',
#  'Chamarajanagar',
#  'Charsadda',
#  'Chhatrapati Shahuji Maharaj Nagar',
#  'Chhota Udepur',
#  'Chhukha',
#  'Chikkaballapura',
#  'Chilas',
#  'Chin State',
#  'Chiniot',
#  'Chitral',
#  'Chittagong',
#  'Cuddapah',
#  'Dadra & Nagar Haveli',
#  'Dadu',
#  'Daga',
#  'Dakshin Bastar Dantewada',
#  'Dang',
#  'Dera Bugti',
#  'Dera Ghazi Khan',
#  'Dera Ismail Khan',
#  'Dhaka',
#  'Dhawalagiri',
#  'Dibang Valley',
#  'Dohad',
#  'East District',
#  'East Jaintia Hills',
#  'EastGodavari',
#  'Eastern',
#  'Faisalabad',
#  'Farkhor',
#  'Gadchiroli',
# ...

# %%
two_not_one = set(df2['polygon_name']).difference(df1['start_polygon_name'])

# %%
two_not_one
# Out:
# {'Baloda Bazar',
#  'Barabanki',
#  'Baramulla',
#  'Bauda',
#  'Chamrajnagar',
#  'Chandigarh',
#  'Chhota Udaipur',
#  'Chikballapura',
#  'Dadra and Nagar Haveli',
#  'Dahod',
#  'Daman',
#  'Dantewada',
#  'Delhi',
#  'East Godavari',
#  'East Sikkim',
#  'Garhchiroli',
#  'Gir Somnath',
#  'Jaintia Hills',
#  'Janjgir-Champa',
#  'Kaimur',
#  'Karaikal',
#  'Lakhimpur Kheri',
#  'Lakshadweep',
#  'Lawangtlai',
#  'Maharajganj',
#  'Mahe',
#  'Mahisagar',
#  'Mumbai City',
#  'Mumbai Suburban',
#  'Nagappattinam',
#  'North 24 Parganas',
#  'North Sikkim',
#  'North and Middle Andaman',
#  'Pakur',
#  'Pashchim Medinipur',
#  'Ranga Reddy',
#  'Sant Ravi Das Nagar',
#  'Saraikela-kharsawan',
#  'Shravasti',
#  'Shupiyan',
#  'Siddharth Nagar',
#  'South 24 Parganas',
#  'South Andaman',
#  'South Sikkim',
#  'Sultanpur',
#  'The Dangs',
#  'Virudunagar',
#  'West Godavari',
#  'West Sikkim',
#  'Y.S.R.',
#  'Yanam'}

# %%
n = len(two_not_one)

# %%
n
# Out:
# 51

# %%
names1
# Out:
# array(['Sirohi', 'Dharmapuri', 'Srikakulam', 'Rajouri', 'Shajapur',
#        'Purba Champaran', 'Palwal', 'EastGodavari', 'Ashoknagar',
#        'West Tripura', 'Chandauli', 'Karur', 'Baudh', 'Kodarma', 'Kasur',
#        'Baramula', 'Ghazipur', 'Peren', 'Chandrapur', 'Nagpur',
#        'Ghaziabad', 'Kolar', 'Tumkur', 'Bijapur', 'Mungeli',
#        'Banas Kantha', 'North Central', 'Lumbini', 'Dakshina Kannada',
#        'Gurdaspur', 'Bilaspur', 'Kurukshetra', 'Parbhani', 'Mahbubnagar',
#        'Kosi', 'Kokrajhar', 'Mandi Bahauddin', 'Jaisalmer', 'Karimnagar',
#        'Lahore', 'Narmada', 'Khulna', 'Debagarh', 'Palghar', 'Kachchh',
#        'Madhubani', 'Mahasamund', 'Purba Medinipur', 'East Garo Hills',
#        'Charsadda', 'Kota Banda Aceh', 'Sitapur', 'Sundargarh', 'Rampur',
#        'Karak', 'Khammam', 'East Nimar', 'West District', 'Indore',
#        'Singrauli', 'Hamirpur', 'Udalguri', 'Koriya', 'Bahawalnagar',
# ...

# %%
df1
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
df2
# Out:
#       polygon_id              polygon_name        lat       long
# 0      IND.1.2_1  North and Middle Andaman  12.611239  92.831654
# 1      IND.1.3_1             South Andaman  11.723203  92.701110
# 2     IND.10.1_1                 North Goa  15.604441  74.001724
# 3     IND.10.2_1                 South Goa  15.219614  74.115281
# 4    IND.11.10_1                     Dahod  22.835854  74.255678
# ..           ...                       ...        ...        ...
# 652    IND.7.8_1                 Dantewada  18.864065  81.383395
# 653    IND.7.9_1                  Dhamtari  20.708454  81.548130
# 654    IND.8.1_1    Dadra and Nagar Haveli  20.273360  73.004499
# 655    IND.9.1_1                     Daman  20.420005  72.863763
# 656    IND.9.2_1                       Diu  20.718175  70.932383
#
# [657 rows x 4 columns]

# %%
filter = (df1['start_polygon_name'] == 'Baloda Bazaar')
df1.loc[filter,'start_polygon_name'] = 'Baloda Bazar'
df1[filter]
# Out:
#          Unnamed: 0         date_time start_polygon_name  end_polygon_name  \
# 1028           1028  2021-08-12 00:00       Baloda Bazar           Mungeli
# 3330           3330  2021-08-12 00:00       Baloda Bazar        Mahasamund
# 4123           4123  2021-08-12 00:00       Baloda Bazar            Raipur
# 4549           4549  2021-08-12 00:00       Baloda Bazar          Bilaspur
# 5068           5068  2021-08-12 00:00       Baloda Bazar          Bemetara
# ...             ...               ...                ...               ...
# 7723045        4610  2021-11-29 16:00       Baloda Bazar  Janjgir - Champa
# 7723945        5510  2021-11-29 16:00       Baloda Bazar           Raigarh
# 7726244        7809  2021-11-29 16:00       Baloda Bazar          Bemetara
# 7726480        8045  2021-11-29 16:00       Baloda Bazar            Raipur
# 7729319       10884  2021-11-29 16:00       Baloda Bazar     Baloda Bazaar
#
#          length_km  n_baseline
# 1028     18.593487        23.6
# ...

# %%
filter = (df1['end_polygon_name']== 'Baloda Bazaar')
df1.loc[filter,'end_polygon_name'] = 'Baloda Bazar'
df1[filter]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 3261           3261  2021-08-12 00:00            Mungeli     Baloda Bazar
# 4368           4368  2021-08-12 00:00           Bilaspur     Baloda Bazar
# 4369           4369  2021-08-12 00:00             Raipur     Baloda Bazar
# 4376           4376  2021-08-12 00:00         Mahasamund     Baloda Bazar
# 5470           5470  2021-08-12 00:00   Janjgir - Champa     Baloda Bazar
# ...             ...               ...                ...              ...
# 7727575        9140  2021-11-29 16:00            Mungeli     Baloda Bazar
# 7727583        9148  2021-11-29 16:00               Durg     Baloda Bazar
# 7728341        9906  2021-11-29 16:00           Bilaspur     Baloda Bazar
# 7728831       10396  2021-11-29 16:00         Mahasamund     Baloda Bazar
# 7729319       10884  2021-11-29 16:00       Baloda Bazar     Baloda Bazar
#
#          length_km  n_baseline
# 3261     18.161509        29.0
# ...

# %%
filt = (df1['start_polygon_name'] == df1['end_polygon_name'])
df1[filt]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 5                 5  2021-08-12 00:00            Rajouri          Rajouri
# 42               42  2021-08-12 00:00            Bijapur          Bijapur
# 43               43  2021-08-12 00:00           Baramula         Baramula
# 44               44  2021-08-12 00:00             Sirohi           Sirohi
# 47               47  2021-08-12 00:00            Mungeli          Mungeli
# ...             ...               ...                ...              ...
# 7730021       11586  2021-11-29 16:00              Baksa            Baksa
# 7730075       11640  2021-11-29 16:00          Pathankot        Pathankot
# 7730076       11641  2021-11-29 16:00             Jhabua           Jhabua
# 7730084       11649  2021-11-29 16:00         Sheikhpura       Sheikhpura
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
#
#          length_km  n_baseline
# 5         0.111491      3902.6
# ...

# %%
filter2 = (df1['start_polygon_name'] == 'Bara Banki')
df1.loc[filter2,'start_polygon_name'] = 'Barabanki'
df1[filter2]
# Out:
#          Unnamed: 0         date_time start_polygon_name  end_polygon_name  \
# 764             764  2021-08-12 00:00          Barabanki         Gopalganj
# 1760           1760  2021-08-12 00:00          Barabanki        Kushinagar
# 1788           1788  2021-08-12 00:00          Barabanki  Sant Kabir Nagar
# 2325           2325  2021-08-12 00:00          Barabanki            Deoria
# 2748           2748  2021-08-12 00:00          Barabanki          Bahraich
# ...             ...               ...                ...               ...
# 7727127        8692  2021-11-29 16:00          Barabanki             Gonda
# 7728265        9830  2021-11-29 16:00          Barabanki        North East
# 7728516       10081  2021-11-29 16:00          Barabanki         Moradabad
# 7728698       10263  2021-11-29 16:00          Barabanki             Unnao
# 7729585       11150  2021-11-29 16:00          Barabanki            Amethi
#
#           length_km  n_baseline
# 764      318.512374         NaN
# ...

# %%
filter2 = (df1['end_polygon_name'] == 'Bara Banki')
df1.loc[filter2,'end_polygon_name'] = 'Barabanki'
df1[filter2]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 612             612  2021-08-12 00:00            Sitapur        Barabanki
# 2386           2386  2021-08-12 00:00          Gorakhpur        Barabanki
# 3540           3540  2021-08-12 00:00              Kheri        Barabanki
# 4799           4799  2021-08-12 00:00         Rae Bareli        Barabanki
# 4807           4807  2021-08-12 00:00       Shahjahanpur        Barabanki
# ...             ...               ...                ...              ...
# 7727702        9267  2021-11-29 16:00   Sant Kabir Nagar        Barabanki
# 7727703        9268  2021-11-29 16:00              Basti        Barabanki
# 7727713        9278  2021-11-29 16:00            Lucknow        Barabanki
# 7727714        9279  2021-11-29 16:00          Allahabad        Barabanki
# 7727718        9283  2021-11-29 16:00         North East        Barabanki
#
#           length_km  n_baseline
# 612       18.535119        89.0
# ...

# %%
filter3 = (df1['start_polygon_name'] == 'Baramula')
df1.loc[filter3,'start_polygon_name'] = 'Baramulla'
df1[filter3]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 22               22  2021-08-12 00:00          Baramulla         Srinagar
# 31               31  2021-08-12 00:00          Baramulla     Muzzafarabad
# 43               43  2021-08-12 00:00          Baramulla         Baramula
# 54               54  2021-08-12 00:00          Baramulla          Kupwara
# 62               62  2021-08-12 00:00          Baramulla        Bandipore
# ...             ...               ...                ...              ...
# 7718744         309  2021-11-29 16:00          Baramulla           Badgam
# 7718831         396  2021-11-29 16:00          Baramulla        Bandipore
# 7718968         533  2021-11-29 16:00          Baramulla         Anantnag
# 7719564        1129  2021-11-29 16:00          Baramulla         Baramula
# 7729742       11307  2021-11-29 16:00          Baramulla          Kupwara
#
#          length_km  n_baseline
# 22       37.436780       118.2
# ...

# %%
filter3 = (df1['end_polygon_name'] == 'Baramula')
df1.loc[filter3,'end_polygon_name'] = 'Baramulla'
df1[filter3]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 43               43  2021-08-12 00:00          Baramulla        Baramulla
# 1269           1269  2021-08-12 00:00       Muzzafarabad        Baramulla
# 1347           1347  2021-08-12 00:00          Ganderbal        Baramulla
# 2074           2074  2021-08-12 00:00           Srinagar        Baramulla
# 2075           2075  2021-08-12 00:00            Kupwara        Baramulla
# ...             ...               ...                ...              ...
# 7719564        1129  2021-11-29 16:00          Baramulla        Baramulla
# 7721072        2637  2021-11-29 16:00             Badgam        Baramulla
# 7722140        3705  2021-11-29 16:00           Srinagar        Baramulla
# 7722141        3706  2021-11-29 16:00          Bandipore        Baramulla
# 7729795       11360  2021-11-29 16:00            Kupwara        Baramulla
#
#          length_km  n_baseline
# 43        0.286702      6689.4
# ...

# %%
df2.loc[(df2['polygon_name']=='Bauda'),'polygon_name'] = 'Baudh'
df2.loc[(df2['polygon_name']=='Chamrajnagar'),'polygon_name'] = 'Chamarajanagar'
df2.loc[(df2['polygon_name']=='Chhota Udaipur'),'polygon_name'] = 'Chhota Udepur'
df2.loc[(df2['polygon_name']=='Chikballapura'),'polygon_name'] = 'Chikkaballapura'
df2.loc[(df2['polygon_name']=='Dadra and Nagar Haveli'),'polygon_name'] = 'Dadra & Nagar Haveli'
df2.loc[(df2['polygon_name']=='Dantewada'),'polygon_name'] = 'Dakshin Bastar Dantewada'
df2.loc[(df2['polygon_name']=='East Godavari'),'polygon_name'] = 'EastGodavari'
df2.loc[(df2['polygon_name']=='Garhchiroli'),'polygon_name'] = 'Gadchiroli'
df2.loc[(df2['polygon_name']=='Gir Somnath'),'polygon_name'] = 'Gir-Somnath'
df2.loc[(df2['polygon_name']=='Jaintia Hills'),'polygon_name'] = 'East Jaintia Hills'
df2.loc[(df2['polygon_name']=='Janjgir-Champa'),'polygon_name'] = 'Janjgir - Champa'
df2.loc[(df2['polygon_name']=='Kaimur'),'polygon_name'] = 'Kaimur (Bhabua)'
df2.loc[(df2['polygon_name']=='Lakhimpur Kheri'),'polygon_name'] = 'Kheri'
df2.loc[(df2['polygon_name']=='Lawangtlai'),'polygon_name'] = 'Lawngtlai'
df2.loc[(df2['polygon_name']=='Maharajganj'),'polygon_name'] = 'Mahrajganj'
df2.loc[(df2['polygon_name']=='Mumbai Suburban'),'polygon_name'] = 'Mumbai (Suburban)'
df2.loc[(df2['polygon_name']=='Nagappattinam'),'polygon_name'] = 'Nagapattinam'
df2.loc[(df2['polygon_name']=='North 24 Parganas'),'polygon_name'] = 'North Twenty Four Parganas'
df2.loc[(df2['polygon_name']=='North and Middle Andaman'),'polygon_name'] = 'North & Middle Andaman'
df2.loc[(df2['polygon_name']=='Pashchim Medinipur'),'polygon_name'] = 'Paschim Medinipur'
df2.loc[(df2['polygon_name']=='Sant Ravi Das Nagar'),'polygon_name'] = 'Sant Ravidas Nagar (Bhadohi)'
df2.loc[(df2['polygon_name']=='Saraikela-kharsawan'),'polygon_name'] = 'Saraikela Kharsawan'
df2.loc[(df2['polygon_name']=='Shravasti'),'polygon_name'] = 'Shrawasti'
df2.loc[(df2['polygon_name']=='Shupiyan'),'polygon_name'] = 'Shopian'
df2.loc[(df2['polygon_name']=='Siddharth Nagar'),'polygon_name'] = 'Siddharthnagar'
df2.loc[(df2['polygon_name']=='South 24 Parganas'),'polygon_name'] = 'South Twenty Four Parganas'
df2.loc[(df2['polygon_name']=='South Andaman'),'polygon_name'] = 'South Andamans'
df2.loc[(df2['polygon_name']=='Virudunagar'),'polygon_name'] = 'Virudhunagar'
df2.loc[(df2['polygon_name']=='The Dangs'),'polygon_name'] = 'Dang'
df2.loc[(df2['polygon_name']=='West Godavari'),'polygon_name'] = 'WestGodavari'
df2.loc[(df2['polygon_name']=='Y.S.R.'),'polygon_name'] = 'Cuddapah'

# %%
filter4 = (df1['start_polygon_name'] == 'Dohad')
df1.loc[filter4,'start_polygon_name'] = 'Dahod'
df1[filter4]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 3106           3106  2021-08-12 00:00              Dahod             Dhar
# 5349           5349  2021-08-12 00:00              Dahod     Panch Mahals
# 5622           5622  2021-08-12 00:00              Dahod    Chhota Udepur
# 5800           5800  2021-08-12 00:00              Dahod            Anand
# 5840           5840  2021-08-12 00:00              Dahod        Mahisager
# ...             ...               ...                ...              ...
# 7727490        9055  2021-11-29 16:00              Dahod          Bharuch
# 7727711        9276  2021-11-29 16:00              Dahod            Kheda
# 7728376        9941  2021-11-29 16:00              Dahod    Surendranagar
# 7730036       11601  2021-11-29 16:00              Dahod         Vadodara
# 7730037       11602  2021-11-29 16:00              Dahod           Jhabua
#
#           length_km  n_baseline
# 3106      86.863519         NaN
# ...

# %%
filter4 = (df1['end_polygon_name'] == 'Dohad')
df1.loc[filter4,'end_polygon_name'] = 'Dahod'
df1[filter4]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 3483           3483  2021-08-12 00:00          Mahisager            Dahod
# 5042           5042  2021-08-12 00:00            Bharuch            Dahod
# 5043           5043  2021-08-12 00:00           Vadodara            Dahod
# 5045           5045  2021-08-12 00:00             Ratlam            Dahod
# 6334           6334  2021-08-12 00:00              Kheda            Dahod
# ...             ...               ...                ...              ...
# 7723517        5082  2021-11-29 16:00          Ahmadabad            Dahod
# 7723520        5085  2021-11-29 16:00               Dhar            Dahod
# 7725061        6626  2021-11-29 16:00             Indore            Dahod
# 7725062        6627  2021-11-29 16:00             Jhabua            Dahod
# 7725065        6630  2021-11-29 16:00           Vadodara            Dahod
#
#           length_km  n_baseline
# 3483      24.412704        90.0
# ...

# %%
filter5 = (df1['start_polygon_name'] == 'Mahisager')
df1.loc[filter5,'start_polygon_name'] = 'Mahisagar'
df1[filter5]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 1402           1402  2021-08-12 00:00          Mahisagar        Mahisager
# 1427           1427  2021-08-12 00:00          Mahisagar         Aravalli
# 2502           2502  2021-08-12 00:00          Mahisagar         Vadodara
# 2785           2785  2021-08-12 00:00          Mahisagar     Panch Mahals
# 3483           3483  2021-08-12 00:00          Mahisagar            Dahod
# ...             ...               ...                ...              ...
# 7725807        7372  2021-11-29 16:00          Mahisagar            Anand
# 7726564        8129  2021-11-29 16:00          Mahisagar            Kheda
# 7727817        9382  2021-11-29 16:00          Mahisagar        Ahmadabad
# 7728928       10493  2021-11-29 16:00          Mahisagar      Gandhinagar
# 7730034       11599  2021-11-29 16:00          Mahisagar         Vadodara
#
#          length_km  n_baseline
# 1402      0.099180      7851.0
# ...

# %%
filter5 = (df1['end_polygon_name'] == 'Mahisager')
df1.loc[filter5,'end_polygon_name'] = 'Mahisagar'
df1[filter5]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 1402           1402  2021-08-12 00:00          Mahisagar        Mahisagar
# 2264           2264  2021-08-12 00:00           Vadodara        Mahisagar
# 3363           3363  2021-08-12 00:00           Aravalli        Mahisagar
# 4642           4642  2021-08-12 00:00              Kheda        Mahisagar
# 4645           4645  2021-08-12 00:00          Ahmadabad        Mahisagar
# ...             ...               ...                ...              ...
# 7719148         713  2021-11-29 16:00           Banswara        Mahisagar
# 7719149         714  2021-11-29 16:00              Dahod        Mahisagar
# 7719716        1281  2021-11-29 16:00              Kheda        Mahisagar
# 7719717        1282  2021-11-29 16:00           Vadodara        Mahisagar
# 7721196        2761  2021-11-29 16:00          Ahmadabad        Mahisagar
#
#          length_km  n_baseline
# 1402      0.099180      7851.0
# ...

# %%
two_not_one = set(df2['polygon_name']).difference(df1['start_polygon_name'])
(two_not_one)
# Out:
# {'Chandigarh',
#  'Daman',
#  'Delhi',
#  'East Sikkim',
#  'Karaikal',
#  'Lakshadweep',
#  'Mahe',
#  'Mumbai City',
#  'North Sikkim',
#  'Pakur',
#  'Ranga Reddy',
#  'South Sikkim',
#  'Sultanpur',
#  'West Sikkim',
#  'Yanam'}

# %%
one_not_two = set(df1["start_polygon_name"]).difference(df2['polygon_name'])
one_not_two
# Out:
# {'Abbottabad',
#  'Aceh Besar',
#  'Aceh Jaya',
#  'Aceh Tengah',
#  'Aceh Utara',
#  'Anjaw',
#  'Attock',
#  'Ayeyarwady',
#  'Badin',
#  'Bagmati',
#  'Bago',
#  'Bahawalnagar',
#  'Bahawalpur',
#  'Bajaur',
#  'Bannu',
#  'Barisal',
#  'Barkhan',
#  'Batagram',
#  'Bhakkar',
#  'Bheri',
#  'Bireuen',
#  'Bumthang',
#  'Buner',
#  'Central',
#  'Chakwal',
#  'Charsadda',
#  'Chhatrapati Shahuji Maharaj Nagar',
#  'Chhukha',
#  'Chilas',
#  'Chin State',
#  'Chiniot',
#  'Chitral',
#  'Chittagong',
#  'Dadu',
#  'Daga',
#  'Dera Bugti',
#  'Dera Ghazi Khan',
#  'Dera Ismail Khan',
#  'Dhaka',
#  'Dhawalagiri',
#  'Dibang Valley',
#  'East District',
#  'Eastern',
#  'Faisalabad',
#  'Farkhor',
#  'Gandaki',
#  'Geylegphug',
#  'Ghotki At Mirpur Mathelo',
#  'Gilghit',
#  'Gilgit Wazara',
#  'Gujranwala',
#  'Gujrat',
#  'Ha',
#  'Hafizabad',
#  'Hamadoni',
#  'Hangu',
#  'Haripur',
#  'Harnai',
#  'Ishkoshim',
#  'Islamabad',
#  'Jacobabad',
#  'Jaffarabad',
#  'Jamshoro',
# ...

# %%
filter6 = (df1['start_polygon_name'] == 'Pakaur')
df1.loc[filter6,'start_polygon_name'] = 'Pakur'
df1[filter6]
# Out:
#          Unnamed: 0         date_time start_polygon_name  \
# 929             929  2021-08-12 00:00              Pakur
# 1809           1809  2021-08-12 00:00              Pakur
# 2090           2090  2021-08-12 00:00              Pakur
# 3117           3117  2021-08-12 00:00              Pakur
# 4867           4867  2021-08-12 00:00              Pakur
# ...             ...               ...                ...
# 7725904        7469  2021-11-29 16:00              Pakur
# 7726911        8476  2021-11-29 16:00              Pakur
# 7726983        8548  2021-11-29 16:00              Pakur
# 7727581        9146  2021-11-29 16:00              Pakur
# 7727641        9206  2021-11-29 16:00              Pakur
#
#                    end_polygon_name   length_km  n_baseline
# 929      North Twenty Four Parganas  226.475190         NaN
# 1809                          Dumka   46.322600        23.0
# 2090                        Birbhum   24.114893       136.4
# ...

# %%
filter6 = (df1['end_polygon_name'] == 'Pakaur')
df1.loc[filter6,'end_polygon_name'] = 'Pakur'
df1[filter6]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 9537           9537  2021-08-12 00:00        Murshidabad            Pakur
# 10079         10079  2021-08-12 00:00            Kolkata            Pakur
# 10089         10089  2021-08-12 00:00              Godda            Pakur
# 10122         10122  2021-08-12 00:00          Sahibganj            Pakur
# 10401         10401  2021-08-12 00:00              Pakur            Pakur
# ...             ...               ...                ...              ...
# 7728961       10526  2021-11-29 16:00         Barddhaman            Pakur
# 7728970       10535  2021-11-29 16:00             Maldah            Pakur
# 7728983       10548  2021-11-29 16:00          Bhagalpur            Pakur
# 7729387       10952  2021-11-29 16:00            Birbhum            Pakur
# 7729390       10955  2021-11-29 16:00        Murshidabad            Pakur
#
#           length_km  n_baseline
# 9537      18.264700       166.6
# ...

# %%
filter7 = (df1['start_polygon_name'] == 'Rangareddi')
df1.loc[filter7,'start_polygon_name'] = 'Ranga Reddy'
df1[filter7]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 341             341  2021-08-12 00:00        Ranga Reddy        Hyderabad
# 1100           1100  2021-08-12 00:00        Ranga Reddy       Chandrapur
# 1624           1624  2021-08-12 00:00        Ranga Reddy           Guntur
# 1807           1807  2021-08-12 00:00        Ranga Reddy          Kurnool
# 1885           1885  2021-08-12 00:00        Ranga Reddy          Khammam
# ...             ...               ...                ...              ...
# 7727602        9167  2021-11-29 16:00        Ranga Reddy       North West
# 7727687        9252  2021-11-29 16:00        Ranga Reddy       South East
# 7729482       11047  2021-11-29 16:00        Ranga Reddy        Osmanabad
# 7729603       11168  2021-11-29 16:00        Ranga Reddy       North East
# 7729738       11303  2021-11-29 16:00        Ranga Reddy         Chittoor
#
#            length_km  n_baseline
# 341         4.053944     33295.8
# ...

# %%
filter7 = (df1['end_polygon_name'] == 'Rangareddi')
df1.loc[filter7,'end_polygon_name'] = 'Ranga Reddy'
df1[filter7]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 104             104  2021-08-12 00:00       EastGodavari      Ranga Reddy
# 734             734  2021-08-12 00:00        Mahbubnagar      Ranga Reddy
# 1452           1452  2021-08-12 00:00         Karimnagar      Ranga Reddy
# 2374           2374  2021-08-12 00:00           Gulbarga      Ranga Reddy
# 3502           3502  2021-08-12 00:00            Khammam      Ranga Reddy
# ...             ...               ...                ...              ...
# 7727276        8841  2021-11-29 16:00            Khordha      Ranga Reddy
# 7727277        8842  2021-11-29 16:00            Lucknow      Ranga Reddy
# 7727281        8846  2021-11-29 16:00          South Goa      Ranga Reddy
# 7727282        8847  2021-11-29 16:00            Kurnool      Ranga Reddy
# 7729879       11444  2021-11-29 16:00           Gulbarga      Ranga Reddy
#
#            length_km  n_baseline
# 104       365.737932        74.4
# ...

# %%
df1
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
one_not_two
# Out:
# {'Abbottabad',
#  'Aceh Besar',
#  'Aceh Jaya',
#  'Aceh Tengah',
#  'Aceh Utara',
#  'Anjaw',
#  'Attock',
#  'Ayeyarwady',
#  'Badin',
#  'Bagmati',
#  'Bago',
#  'Bahawalnagar',
#  'Bahawalpur',
#  'Bajaur',
#  'Bannu',
#  'Barisal',
#  'Barkhan',
#  'Batagram',
#  'Bhakkar',
#  'Bheri',
#  'Bireuen',
#  'Bumthang',
#  'Buner',
#  'Central',
#  'Chakwal',
#  'Charsadda',
#  'Chhatrapati Shahuji Maharaj Nagar',
#  'Chhukha',
#  'Chilas',
#  'Chin State',
#  'Chiniot',
#  'Chitral',
#  'Chittagong',
#  'Dadu',
#  'Daga',
#  'Dera Bugti',
#  'Dera Ghazi Khan',
#  'Dera Ismail Khan',
#  'Dhaka',
#  'Dhawalagiri',
#  'Dibang Valley',
#  'East District',
#  'Eastern',
#  'Faisalabad',
#  'Farkhor',
#  'Gandaki',
#  'Geylegphug',
#  'Ghotki At Mirpur Mathelo',
#  'Gilghit',
#  'Gilgit Wazara',
#  'Gujranwala',
#  'Gujrat',
#  'Ha',
#  'Hafizabad',
#  'Hamadoni',
#  'Hangu',
#  'Haripur',
#  'Harnai',
#  'Ishkoshim',
#  'Islamabad',
#  'Jacobabad',
#  'Jaffarabad',
#  'Jamshoro',
# ...

# %%
two_not_one
# Out:
# {'Chandigarh',
#  'Daman',
#  'Delhi',
#  'East Sikkim',
#  'Karaikal',
#  'Lakshadweep',
#  'Mahe',
#  'Mumbai City',
#  'North Sikkim',
#  'Pakur',
#  'Ranga Reddy',
#  'South Sikkim',
#  'Sultanpur',
#  'West Sikkim',
#  'Yanam'}

# %%
df1
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
df1.loc[df1['start_polygon_name'] == 'Central', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'East District', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North Central', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North District', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North East', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North West', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'North Western', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'South District', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'South East', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'South West', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['start_polygon_name'] == 'West District', 'start_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'Central', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'East District', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North Central', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North District', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North East', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North West', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'North Western', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'South District', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'South East', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'South West', 'end_polygon_name'] = 'Delhi'
df1.loc[df1['end_polygon_name'] == 'West District', 'end_polygon_name'] = 'Delhi'

# %%
two_not_one = set(df2['polygon_name']).difference(df1['start_polygon_name'])
(two_not_one)
# Out:
# {'Chandigarh',
#  'Daman',
#  'East Sikkim',
#  'Karaikal',
#  'Lakshadweep',
#  'Mahe',
#  'Mumbai City',
#  'North Sikkim',
#  'South Sikkim',
#  'Sultanpur',
#  'West Sikkim',
#  'Yanam'}

# %%
one_not_two = set(df1["start_polygon_name"]).difference(df2['polygon_name'])
one_not_two
# Out:
# {'Abbottabad',
#  'Aceh Besar',
#  'Aceh Jaya',
#  'Aceh Tengah',
#  'Aceh Utara',
#  'Anjaw',
#  'Attock',
#  'Ayeyarwady',
#  'Badin',
#  'Bagmati',
#  'Bago',
#  'Bahawalnagar',
#  'Bahawalpur',
#  'Bajaur',
#  'Bannu',
#  'Barisal',
#  'Barkhan',
#  'Batagram',
#  'Bhakkar',
#  'Bheri',
#  'Bireuen',
#  'Bumthang',
#  'Buner',
#  'Chakwal',
#  'Charsadda',
#  'Chhatrapati Shahuji Maharaj Nagar',
#  'Chhukha',
#  'Chilas',
#  'Chin State',
#  'Chiniot',
#  'Chitral',
#  'Chittagong',
#  'Dadu',
#  'Daga',
#  'Dera Bugti',
#  'Dera Ghazi Khan',
#  'Dera Ismail Khan',
#  'Dhaka',
#  'Dhawalagiri',
#  'Dibang Valley',
#  'Eastern',
#  'Faisalabad',
#  'Farkhor',
#  'Gandaki',
#  'Geylegphug',
#  'Ghotki At Mirpur Mathelo',
#  'Gilghit',
#  'Gilgit Wazara',
#  'Gujranwala',
#  'Gujrat',
#  'Ha',
#  'Hafizabad',
#  'Hamadoni',
#  'Hangu',
#  'Haripur',
#  'Harnai',
#  'Ishkoshim',
#  'Islamabad',
#  'Jacobabad',
#  'Jaffarabad',
#  'Jamshoro',
#  'Janakpur',
#  'Jhal Magsi',
# ...

# %%
filter10 = (df1['end_polygon_name'] == 'Chhatrapati Shahuji Maharaj Nagar')
df1.loc[filter10,'end_polygon_name'] = 'Amethi'
df1[filter10]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 533             533  2021-08-12 00:00          Chandauli           Amethi
# 534             534  2021-08-12 00:00           Lalitpur           Amethi
# 1144           1144  2021-08-12 00:00     Ambedkar Nagar           Amethi
# 1145           1145  2021-08-12 00:00         Pratapgarh           Amethi
# 2050           2050  2021-08-12 00:00            Hardwar           Amethi
# ...             ...               ...                ...              ...
# 7726473        8038  2021-11-29 16:00              Patna           Amethi
# 7726474        8039  2021-11-29 16:00          Allahabad           Amethi
# 7726475        8040  2021-11-29 16:00             Amethi           Amethi
# 7726478        8043  2021-11-29 16:00           Azamgarh           Amethi
# 7726484        8049  2021-11-29 16:00            Jaunpur           Amethi
#
#           length_km  n_baseline
# 533      149.418923         NaN
# ...

# %%
filter12 = (df1['start_polygon_name'] == 'Chhatrapati Shahuji Maharaj Nagar')
df1.loc[filter12,'start_polygon_name'] = 'Amethi'
df1[filter12]
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 2516           2516  2021-08-12 00:00             Amethi         Azamgarh
# 3017           3017  2021-08-12 00:00             Amethi           Amethi
# 3650           3650  2021-08-12 00:00             Amethi        Allahabad
# 4795           4795  2021-08-12 00:00             Amethi   Ambedkar Nagar
# 5269           5269  2021-08-12 00:00             Amethi         Faizabad
# ...             ...               ...                ...              ...
# 7721351        2916  2021-11-29 16:00             Amethi           Amethi
# 7721453        3018  2021-11-29 16:00             Amethi        Chandauli
# 7722769        4334  2021-11-29 16:00             Amethi       Rae Bareli
# 7728433        9998  2021-11-29 16:00             Amethi         Varanasi
# 7729117       10682  2021-11-29 16:00             Amethi        Allahabad
#
#           length_km  n_baseline
# 2516      17.538599        40.6
# ...

# %%
df1
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
df = df1[~df1['start_polygon_name'].isin(['Abbottabad',
 'Aceh Besar',
 'Aceh Jaya',
 'Aceh Tengah',
 'Aceh Utara',
 'Attock',
 'Ayeyarwady',
 'Badin',
 'Bagmati',
 'Bago',
 'Bahawalnagar',
 'Bahawalpur',
 'Bajaur',
 'Bannu',
 'Barisal',
 'Barkhan',
 'Batagram',
 'Bhakkar',
 'Bheri',
 'Bireuen',
 'Bumthang',
 'Buner',
 'Chakwal',
 'Charsadda',
 'Chhukha',
 'Chilas',
 'Chin State',
 'Chiniot',
 'Chitral',
 'Chittagong',
 'Dadu',
 'Daga',
 'Dera Bugti',
 'Dera Ghazi Khan',
 'Dera Ismail Khan',
 'Dhaka',
 'Dhawalagiri',
 'Faisalabad',
 'Farkhor',
 'Gandaki',
 'Geylegphug',
 'Ghotki At Mirpur Mathelo',
 'Gilghit',
 'Gilgit Wazara',
 'Gujranwala',
 'Gujrat',
 'Ha',
 'Hafizabad',
 'Hamadoni',
 'Hangu',
 'Haripur',
 'Harnai',
 'Ishkoshim',
 'Islamabad',
 'Jacobabad',
 'Jaffarabad',
 'Jamshoro',
 'Janakpur',
 'Jhal Magsi',
 'Jhang',
 'Jhelum',
 'Jilikul',
 'Kachhi',
 'Kachin State',
 'Karak',
 'Karnali',
 'Kashmore',
 'Kasur',
 'Kayah State',
 'Kayin State',
 'Khairpur',
 'Khanewal',
 'Khulna',
 'Khushab',
 'Khyber',
 'Killa Saifullah',
 'Kohat',
 'Kohlu',
 'Kolkhozobod',
 'Kosi',
 'Kota Banda Aceh',
 'Kota Lhoksumawe',
 'Kurram',
 'Lahore',
 'Lakki Marwat',
 'Larkana',
 'Layyah',
 'Lhuntshi',
 'Lodhran',
 'Loralai',
 'Lower Dir',
 'Lower Kohistan',
 'Lumbini',
 'Magway',
 'Mahakali',
 'Malakand P.A.',
 'Mandalay',
 'Mandi Bahauddin',
 'Mansehra',
 'Mardan',
 'Matiari',
 'Mechi',
 'Mianwali',
 'Mirpur',
 'Mirpur Khas',
 'Mohmand',
 'Mon State',
 'Mongar',
 'Multan',
 'Musakhel',
 'Muzaffargarh',
 'Muzzafarabad',
 'Nankana Sahib',
 'Narayani',
 'Narowal',
 'Nasirabad',
 'Naushahro Feroze',
 'North Waziristan',
 'Nosiri Khisrav',
 'Nowshera',
 'Okara',
 'Orakzai',
 'Pakpattan',
 'Panj',
 'Paro',
 'Pemagatsel',
 'Peshawar',
 'Pidie',
 'Pishin',
 'Punakha',
 'Qabodiyon',
 'Qumsangir',
 'Rahim Yar Khan',
 'Rajanpur',
 'Rajshahi',
 'Rakhine State',
 'Rangpur',
 'Rapti',
 'Rawalpindi',
 'Roshtqala',
 'Sabaragamuwa',
 'Sagaing',
 'Sagarmatha',
 'Sahiwal',
 'Samchi',
 'Samdrup Jongkhar',
 'Sanghar',
 'Sargodha',
 'Seti',
 'Shahdadkot',
 'Shaheed Benazir Abad',
 'Shahrtuz',
 'Shan State',
 'Shangla',
 'Sheerani',
 'Sheikhupura',
 'Shemgang',
 'Shikarpur',
 'Shughnon',
 'Sialkot',
 'Sibi',
 'Sohbatpur',
 'South Waziristan',
 'Sukkur',
 'Swabi',
 'Swat',
 'Sylhet',
 'Tando Allahyar',
 'Tando Mohammad Khan',
 'Tank',
 'Tashigang',
 'Termiz',
 'Tharparkar',
 'Thatta',
 'Thimphu',
 'Toba Tek Singh',
 'Tongsa',
 'Tribal Territory',
 'Umerkot',
 'Upper Dir',
 'Upper Kohistan',
 'Uva',
 'Vakhsh',
 'Vehari',
 'Wangdi Phodrang',
 'Yangon',
 'Zhob',
 'Ziarat'])]

# %%
df = df[~df['end_polygon_name'].isin(['Abbottabad',
 'Aceh Besar',
 'Aceh Jaya',
 'Aceh Tengah',
 'Aceh Utara',
 'Attock',
 'Ayeyarwady',
 'Badin',
 'Bagmati',
 'Bago',
 'Bahawalnagar',
 'Bahawalpur',
 'Bajaur',
 'Bannu',
 'Barisal',
 'Barkhan',
 'Batagram',
 'Bhakkar',
 'Bheri',
 'Bireuen',
 'Bumthang',
 'Buner',
 'Chakwal',
 'Charsadda',
 'Chhukha',
 'Chilas',
 'Chin State',
 'Chiniot',
 'Chitral',
 'Chittagong',
 'Dadu',
 'Daga',
 'Dera Bugti',
 'Dera Ghazi Khan',
 'Dera Ismail Khan',
 'Dhaka',
 'Dhawalagiri',
 'Faisalabad',
 'Farkhor',
 'Gandaki',
 'Geylegphug',
 'Ghotki At Mirpur Mathelo',
 'Gilghit',
 'Gilgit Wazara',
 'Gujranwala',
 'Gujrat',
 'Ha',
 'Hafizabad',
 'Hamadoni',
 'Hangu',
 'Haripur',
 'Harnai',
 'Ishkoshim',
 'Islamabad',
 'Jacobabad',
 'Jaffarabad',
 'Jamshoro',
 'Janakpur',
 'Jhal Magsi',
 'Jhang',
 'Jhelum',
 'Jilikul',
 'Kachhi',
 'Kachin State',
 'Karak',
 'Karnali',
 'Kashmore',
 'Kasur',
 'Kayah State',
 'Kayin State',
 'Khairpur',
 'Khanewal',
 'Khulna',
 'Khushab',
 'Khyber',
 'Killa Saifullah',
 'Kohat',
 'Kohlu',
 'Kolkhozobod',
 'Kosi',
 'Kota Banda Aceh',
 'Kota Lhoksumawe',
 'Kurram',
 'Lahore',
 'Lakki Marwat',
 'Larkana',
 'Layyah',
 'Lhuntshi',
 'Lodhran',
 'Loralai',
 'Lower Dir',
 'Lower Kohistan',
 'Lumbini',
 'Magway',
 'Mahakali',
 'Malakand P.A.',
 'Mandalay',
 'Mandi Bahauddin',
 'Mansehra',
 'Mardan',
 'Matiari',
 'Mechi',
 'Mianwali',
 'Mirpur',
 'Mirpur Khas',
 'Mohmand',
 'Mon State',
 'Mongar',
 'Multan',
 'Musakhel',
 'Muzaffargarh',
 'Muzzafarabad',
 'Nankana Sahib',
 'Narayani',
 'Narowal',
 'Nasirabad',
 'Naushahro Feroze',
 'North Waziristan',
 'Nosiri Khisrav',
 'Nowshera',
 'Okara',
 'Orakzai',
 'Pakpattan',
 'Panj',
 'Paro',
 'Pemagatsel',
 'Peshawar',
 'Pidie',
 'Pishin',
 'Punakha',
 'Qabodiyon',
 'Qumsangir',
 'Rahim Yar Khan',
 'Rajanpur',
 'Rajshahi',
 'Rakhine State',
 'Rangpur',
 'Rapti',
 'Rawalpindi',
 'Roshtqala',
 'Sabaragamuwa',
 'Sagaing',
 'Sagarmatha',
 'Sahiwal',
 'Samchi',
 'Samdrup Jongkhar',
 'Sanghar',
 'Sargodha',
 'Seti',
 'Shahdadkot',
 'Shaheed Benazir Abad',
 'Shahrtuz',
 'Shan State',
 'Shangla',
 'Sheerani',
 'Sheikhupura',
 'Shemgang',
 'Shikarpur',
 'Shughnon',
 'Sialkot',
 'Sibi',
 'Sohbatpur',
 'South Waziristan',
 'Sukkur',
 'Swabi',
 'Swat',
 'Sylhet',
 'Tando Allahyar',
 'Tando Mohammad Khan',
 'Tank',
 'Tashigang',
 'Termiz',
 'Tharparkar',
 'Thatta',
 'Thimphu',
 'Toba Tek Singh',
 'Tongsa',
 'Tribal Territory',
 'Umerkot',
 'Upper Dir',
 'Upper Kohistan',
 'Uva',
 'Vakhsh',
 'Vehari',
 'Wangdi Phodrang',
 'Yangon',
 'Zhob',
 'Ziarat'])]

# %%
df2
# Out:
#       polygon_id              polygon_name        lat       long
# 0      IND.1.2_1    North & Middle Andaman  12.611239  92.831654
# 1      IND.1.3_1            South Andamans  11.723203  92.701110
# 2     IND.10.1_1                 North Goa  15.604441  74.001724
# 3     IND.10.2_1                 South Goa  15.219614  74.115281
# 4    IND.11.10_1                     Dahod  22.835854  74.255678
# ..           ...                       ...        ...        ...
# 652    IND.7.8_1  Dakshin Bastar Dantewada  18.864065  81.383395
# 653    IND.7.9_1                  Dhamtari  20.708454  81.548130
# 654    IND.8.1_1      Dadra & Nagar Haveli  20.273360  73.004499
# 655    IND.9.1_1                     Daman  20.420005  72.863763
# 656    IND.9.2_1                       Diu  20.718175  70.932383
#
# [657 rows x 4 columns]

# %%
one_not_two = set(df["start_polygon_name"]).difference(df2['polygon_name'])
one_not_two
# Out:
# {'Anjaw',
#  'Dibang Valley',
#  'Eastern',
#  'Kiphire',
#  'Kra Daadi',
#  'Kurung Kumey',
#  'Longding',
#  'Longleng',
#  'Nicobars',
#  'Northern',
#  'Siang',
#  'South West Khasi Hills',
#  'Southern',
#  'Upper Siang',
#  'West Jaintia Hills',
#  'Western'}

# %%
df
# Out:
#          Unnamed: 0         date_time start_polygon_name end_polygon_name  \
# 0                 0  2021-08-12 00:00             Sirohi            Jalor
# 1                 1  2021-08-12 00:00             Sirohi             Pali
# 2                 2  2021-08-12 00:00         Dharmapuri   Tiruvannamalai
# 3                 3  2021-08-12 00:00         Srikakulam          Khordha
# 4                 4  2021-08-12 00:00             Sirohi     Chittaurgarh
# ...             ...               ...                ...              ...
# 7730089       11654  2021-11-29 16:00      Surendranagar         Vadodara
# 7730090       11655  2021-11-29 16:00              Sagar         Vadodara
# 7730091       11656  2021-11-29 16:00           Vadodara         Vadodara
# 7730092       11657  2021-11-29 16:00             Kangra        Pathankot
# 7730093       11658  2021-11-29 16:00           Amritsar        Pathankot
#
#           length_km  n_baseline
# 0         20.469569       145.8
# ...

# %%
two_not_one = set(df2['polygon_name']).difference(df['start_polygon_name'])
(two_not_one)
# Out:
# {'Chandigarh',
#  'Daman',
#  'East Sikkim',
#  'Karaikal',
#  'Lakshadweep',
#  'Mahe',
#  'Mumbai City',
#  'North Sikkim',
#  'South Sikkim',
#  'Sultanpur',
#  'West Sikkim',
#  'Yanam'}

# %%
dict = {'polygon_id':['IND.3.1_1', 'IND.3.3_1', 'IND.24.2_1', 'IND.3.6_1', 'IND.3.6_1', 'IND.3.8_1', 'IND.24.4_1', 'IND.1.1_1', 'IND.3.5_1', 'IND.22.8_1', 'IND.3.15_1', 'IND.22.3_1'],
        'polygon_name':['Anjaw', 'Dibang Valley', 'Kiphire', 'Kra Daadi', 'Kurung Kumey', 'Longding', 'Longleng', 'Nicobars', 'Siang', 'South West Khasi Hills', 'Upper Siang', 'West Jaintia Hills'],
        'lat':[27.79866, 28.8129, 25.8188, 27.70389, 27.986368, 26.8728, 26.4902, 7.1205, 28.1473, 25.3259, 28.7589, 25.5021 ],
        'long':[95.90994, 96.1527, 94.8521, 93.69101, 93.157835, 95.3057, 94.8197, 93.7842, 94.7485, 91.2506, 95.2267, 92.3419]
       }
df3 = pd.DataFrame(dict)
df4 = pd.concat([df2, df3], ignore_index = True)

# %%
df4
# Out:
#       polygon_id            polygon_name        lat       long
# 0      IND.1.2_1  North & Middle Andaman  12.611239  92.831654
# 1      IND.1.3_1          South Andamans  11.723203  92.701110
# 2     IND.10.1_1               North Goa  15.604441  74.001724
# 3     IND.10.2_1               South Goa  15.219614  74.115281
# 4    IND.11.10_1                   Dahod  22.835854  74.255678
# ..           ...                     ...        ...        ...
# 664    IND.1.1_1                Nicobars   7.120500  93.784200
# 665    IND.3.5_1                   Siang  28.147300  94.748500
# 666   IND.22.8_1  South West Khasi Hills  25.325900  91.250600
# 667   IND.3.15_1             Upper Siang  28.758900  95.226700
# 668   IND.22.3_1      West Jaintia Hills  25.502100  92.341900
#
# [669 rows x 4 columns]

# %%
one_not_two = set(df["start_polygon_name"]).difference(df4['polygon_name'])
one_not_two
# Out:
# {'Eastern', 'Northern', 'Southern', 'Western'}

# %%
df.to_csv('file1.csv')
df4.to_csv('file2.csv')
